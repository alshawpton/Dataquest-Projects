# %%
import pandas as pd
star_wars = pd.read_csv('C:/Users/alexs/Desktop/Dataquest Projects/Data Files/StarWars.csv', encoding="ISO-8859-1")

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
star_wars['RespondentID'].isnull().sum()
# Out:
# 1

# %%
star_wars = star_wars[star_wars['RespondentID'].notnull()]

# %%
star_wars.shape
# Out:
# (1186, 38)

# %%
yes_no = {'Yes':True,'No':False}

# %%
star_wars['Have you seen any of the 6 films in the Star Wars franchise?'] = star_wars['Have you seen any of the 6 films in the Star Wars franchise?'].map(yes_no)

# %%
star_wars['Have you seen any of the 6 films in the Star Wars franchise?'].value_counts()
# Out:
# True     936
# False    250
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: int64

# %%
star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'] = star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'].map(yes_no)

# %%
star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'].value_counts(dropna=False)
# Out:
# True     552
# NaN      350
# False    284
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, dtype: int64

# %%
star_wars = star_wars.rename(columns={'Which of the following Star Wars films have you seen? Please select all that apply.':'seen1'})

# %%
star_wars = star_wars.rename(columns={'Unnamed: 4':'seen2','Unnamed: 5':'seen3','Unnamed: 6':'seen4','Unnamed: 7':'seen5','Unnamed: 8':'seen6'})

# %%
star_wars.columns[3:9]
# Out:
# Index(['seen1', 'seen2', 'seen3', 'seen4', 'seen5', 'seen6'], dtype='object')

# %%
def seen_movie(movie):
    if pd.notnull(movie):
        return True
    else:
        return False

# %%
test2 = star_wars.iloc[:,3:9].applymap(seen_movie)

# %%
test = star_wars.copy()

# %%
test.iloc[:,3:9] = star_wars.iloc[:,3:9].applymap(seen_movie)

# %%
star_wars.iloc[:,3:9] = star_wars.iloc[:,3:9].applymap(seen_movie)

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
test2 = star_wars.copy()

# %%
j = 1
for i in test2.columns[9:15]:
    test2 = test2.rename(columns={i:'ranking_'+str(j)})
    j += 1

# %%
test2.columns[9:15]
# Out:
# Index(['ranking_1', 'ranking_2', 'ranking_3', 'ranking_4', 'ranking_5',
#        'ranking_6'],
#       dtype='object')

# %%
x = 1
for i in star_wars.columns[9:15]:
    star_wars = star_wars.rename(columns={i:'ranking_'+str(x)})
    x+=1

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'seen1', 'seen2', 'seen3', 'seen4', 'seen5', 'seen6', 'ranking_1',
#        'ranking_2', 'ranking_3', 'ranking_4', 'ranking_5', 'ranking_6',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
#        'Are you familiar with the Expanded Universe?',
#        'Do you consider yourself to be a fan of the Expanded Universe?æ',
#        'Do you consider yourself to be a fan of the Star Trek franchise?',
#        'Gender', 'Age', 'Household Income', 'Education',
# ...

# %%
rank_means = star_wars.iloc[:,9:15].mean()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fix, ax = plt.subplots()
ax1 = ax.bar(range(1,7),rank_means)

# %%
seen_cols = ['seen'+str(i) for i in range(1,7)]
seen_cols
# Out:
# ['seen1', 'seen2', 'seen3', 'seen4', 'seen5', 'seen6']

# %%
seen_sums = star_wars[seen_cols].sum(axis=0)

# %%
fig, ax = plt.subplots()
ax2 = ax.bar(range(1,7), seen_sums)

# %%
males = star_wars[star_wars['Gender']=='Male']
females = star_wars[star_wars['Gender']=='Female']

# %%
males_ranks = males.iloc[:,9:15].mean()
females_ranks = females.iloc[:,9:15].mean()

# %%
males_seen = males[seen_cols].sum()
females_seen = females[seen_cols].sum()

# %%
fig, ax = plt.subplots()
m_ax = ax.bar(range(1,7),males_ranks)

# %%
fig, ax = plt.subplots()
m_ax = ax.bar(range(1,7),males_seen)

# %%
fig, ax = plt.subplots()
f_ax = ax.bar(range(1,7),females_ranks)

# %%
fig, ax = plt.subplots()
f_ax = ax.bar(range(1,7),females_seen)

# %%
chars = pd.read_csv('C:/Users/alexs/Desktop/Dataquest Projects/Data Files/StarWars.csv', encoding="ISO-8859-1")

# %%
characters = [i for i in chars.iloc[0,15:29]]

# %%
characters
# Out:
# ['Han Solo',
#  'Luke Skywalker',
#  'Princess Leia Organa',
#  'Anakin Skywalker',
#  'Obi Wan Kenobi',
#  'Emperor Palpatine',
#  'Darth Vader',
#  'Lando Calrissian',
#  'Boba Fett',
#  'C-3P0',
#  'R2 D2',
#  'Jar Jar Binks',
#  'Padme Amidala',
#  'Yoda']

# %%
old_cols = [i for i in star_wars.columns[15:29]]
old_cols
# Out:
# ['Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28']

# %%
test3 = star_wars.copy()

# %%
for i in range(len(old_cols)):
    star_wars = star_wars.rename(columns={old_cols[i]:characters[i]})

# %%
star_wars.columns[15:29]
# Out:
# Index(['Han Solo', 'Luke Skywalker', 'Princess Leia Organa',
#        'Anakin Skywalker', 'Obi Wan Kenobi', 'Emperor Palpatine',
#        'Darth Vader', 'Lando Calrissian', 'Boba Fett', 'C-3P0', 'R2 D2',
#        'Jar Jar Binks', 'Padme Amidala', 'Yoda'],
#       dtype='object')

# %%
scores = {'Very favorably':2,'Somewhat favorably':1,'Neither favorably nor unfavorably (neutral)':0, 'Unfamiliar (N/A)':np.nan, \
         'Somewhat unfavorably':-1,'Very unfavorably':-2}

# %%
def fav_to_score(favor):
    if pd.isnull(favor):
        return np.nan
    else:
        return scores[favor]

# %%
test3.iloc[:,15:29] = test3.iloc[:,15:29].applymap(fav_to_score)

# %%
test3[test3['Han Solo']<0]['Han Solo'].sum()
# Out:
# -10.0

# %%
overall_scores = test3.iloc[:,15:29].sum()

# %%
positive_scores = test3[test3.iloc[:,15:29]>0].iloc[:,15:29].sum()

# %%
overall_scores
# Out:
# Han Solo                1361.0
# Luke Skywalker          1304.0
# Princess Leia Organa    1280.0
# Anakin Skywalker         598.0
# Obi Wan Kenobi          1319.0
# Emperor Palpatine         47.0
# Darth Vader              391.0
# Lando Calrissian         428.0
# Boba Fett                243.0
# C-3P0                   1140.0
# R2 D2                   1287.0
# Jar Jar Binks           -156.0
# Padme Amidala            393.0
# Yoda                    1330.0
# dtype: float64

# %%
positive_scores
# Out:
# Han Solo                1371.0
# Luke Skywalker          1323.0
# Princess Leia Organa    1304.0
# Anakin Skywalker         759.0
# Obi Wan Kenobi          1341.0
# Emperor Palpatine        363.0
# Darth Vader              791.0
# Lando Calrissian         507.0
# Boba Fett                429.0
# C-3P0                   1177.0
# R2 D2                   1309.0
# Jar Jar Binks            354.0
# Padme Amidala            519.0
# Yoda                    1354.0
# dtype: float64

# %%
test3[test3['Jar Jar Binks']<0]['Jar Jar Binks'].sum()
# Out:
# -510.0

# %%
negative_scores = test3[test3.iloc[:,15:29]<0].iloc[:,15:29].sum()

# %%
negative_scores
# Out:
# Han Solo                -10.0
# Luke Skywalker          -19.0
# Princess Leia Organa    -24.0
# Anakin Skywalker       -161.0
# Obi Wan Kenobi          -22.0
# Emperor Palpatine      -316.0
# Darth Vader            -400.0
# Lando Calrissian        -79.0
# Boba Fett              -186.0
# C-3P0                   -37.0
# R2 D2                   -22.0
# Jar Jar Binks          -510.0
# Padme Amidala          -126.0
# Yoda                    -24.0
# dtype: float64
